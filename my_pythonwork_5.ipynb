# %%
#practice day 5

# %%
implementation of for loops on dicyionaries :

# %%
instagram / facebook :

# %%
create an account on the above application :

    User account :

# %%
 user = {'username':'codetraining','firstname':'code','lastname':'training','dob':'01-03-2021','password': 112233 }

# %%
print(user)
# Out:
# {'username': 'codetraining', 'firstname': 'code', 'lastname': 'training', 'dob': '01-03-2021', 'password': 112233}

# %%
type(user)
# Out:
# dict

# %%
#genral syntax of a for loop in dictionary:

for key(temp_var),(temp_var2)value in mainvar.items():
    print(key)
    print(value)

# %%
for a ,b in user.items():
    print(a)
    print(b)
# Out:
# username
# codetraining
# firstname
# code
# lastname
# training
# dob
# 01-03-2021
# password
# 112233

# %%
#enhancement of code :

# %%
for a ,b in user.items():
    print(f"key:{a}")
    print(f"value{b}\n")
# Out:
# key:username
# valuecodetraining
#
# key:firstname
# valuecode
#
# key:lastname
# valuetraining
#
# key:dob
# value01-03-2021
#
# key:password
# value112233

# %%
# req: from the above dictionary i want only keys to be printed :

# %%
for a in user.keys():
    print(f"keys:{a}")
# Out:
# keys:username
# keys:firstname
# keys:lastname
# keys:dob
# keys:password

# %%
# req :from the above dictionary i want only values to be printed :

# %%
for a in user.values():
    print(f"values:{a}")
# Out:
# values:codetraining
# values:code
# values:training
# values:01-03-2021
# values:112233

# %%
# making lists

# %%
students:["mehvish","arhaam","hiba","moin","vali","sufyan","ziad"]

# %%
type(students)
# Out:
# list

# %%
print(students)
# Out:
# ['mehvish', 'arhaam', 'hiba', 'moin', 'vali', 'sufyan', 'ziad']

# %%
# req: i want to delete mehvish from the list.

# %%
print(students[0])
# Out:
# mehvish

# %%
del students[0] #permanent deleting

# %%
print(students)
# Out:
# ['arhaam', 'hiba', 'moin', 'vali', 'sufyan', 'ziad']

# %%
# we can see index number one mehvish got deleted by using del method.

# %%
# method which is used for temprory deleting is , .pop() method lets see how to use it:

# %%
*note : whenever we will be using pop method it will be deleting the items from the end of list

# %%
print(students)
# Out:
# ['arhaam', 'hiba', 'moin', 'vali', 'sufyan', 'ziad']

# %%
s = students.pop()

# %%
print(students)
# Out:
# ['arhaam', 'hiba', 'moin', 'vali', 'sufyan']

# %%
# we can see that ziad is poped out from the list

# %%
print(s) # pop will be creating a carbon copy of the deleted items.
# Out:
# ziad

# %%
print(user)
# Out:
# {'username': 'codetraining', 'firstname': 'code', 'lastname': 'training', 'dob': '01-03-2021', 'password': 112233}

# %%
#req: username should be deleted

# %%
del user['username']

# %%
print(user)
# Out:
# {'firstname': 'code', 'lastname': 'training', 'dob': '01-03-2021', 'password': 112233}

# %%
a = user.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 a = user.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
a = user.pop(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 a = user.pop(1)
#
# KeyError: 1

# %%
a = user.pop('password') # perfect way to write

# %%
print(user)
# Out:
# {'firstname': 'code', 'lastname': 'training', 'dob': '01-03-2021'}

# %%
print(a) #it will keep the value.
# Out:
# 112233

# %%
# conditional statements :

# %%
medicine = ["paracetamol","diaclogem","dolo","ibugesic","glycil","panadol"]

# %%
print(medicine)
# Out:
# ['paracetamol', 'diaclogem', 'dolo', 'ibugesic', 'glycil', 'panadol']

# %%
# req : correct the format of all the medicine  title case and for only dolo it  should be uppercase

# %%
for x in medicine:
    if x=="dolo":
        print(x.upper())
    else:
        print(x.title())
# Out:
# Paracetamol
# Diaclogem
# DOLO
# Ibugesic
# Glycil
# Panadol

# %%
#checking for equality

# %%
x = "dolo"

# %%
x == "DOLO"
# Out:
# False

# %%
# numerical comparision.

# %%
age = 21 #integer

# %%
age == 21
# Out:
# True

# %%
if age >= 18:
    print("you are ready to vote")
else:
    print("try next year")
# Out:
# you are ready to vote

# %%
if age >= 18 :
    print("you are old enough to vote")
else:
    print("please try next year")
# Out:
# you are old enough to vote
